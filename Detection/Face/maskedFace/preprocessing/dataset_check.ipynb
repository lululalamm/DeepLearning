# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import random

# %%
csv_path = "aihub_dataset/FaceMask/id_balanced/saved_train_id_balanced.csv"

# %%
df = pd.read_csv(csv_path,header=None)

# %%
df
# Out:
#               0                                                  1  2    3  \
# 0        901011  /data/notebook/shared/aihub_dataset/FaceMask/T...  F  STD
# 1        901011  /data/notebook/shared/aihub_dataset/FaceMask/T...  F  STD
# 2        901011  /data/notebook/shared/aihub_dataset/FaceMask/T...  F  REI
# 3        901011  /data/notebook/shared/aihub_dataset/FaceMask/T...  F  STD
# 4        901011  /data/notebook/shared/aihub_dataset/FaceMask/T...  F  STD
# ...         ...                                                ... ..  ...
# 119750     1661  /data/notebook/shared/aihub_dataset/FaceMask/T...  M  CRS
# 119751      820  /data/notebook/shared/aihub_dataset/FaceMask/T...  F  CRS
# 119752   831018  /data/notebook/shared/aihub_dataset/FaceMask/T...  F  REI
# 119753  1007015  /data/notebook/shared/aihub_dataset/FaceMask/T...  F  STD
# 119754     2309  /data/notebook/shared/aihub_dataset/FaceMask/T...  M  CRS
#
#             4     5                     6  7
# ...

# %%
names = df[6]

# %%
image_base = "aihub_dataset/FaceMask/id_balanced/images/"

# %%
samples = random.sample(list(names.values),30)

# %%
plt.figure(figsize=(10,10))
c=1
for s in samples:
    img_path = os.path.join(image_base,s)
    img = cv2.cvtColor(cv2.imread(img_path),cv2.COLOR_BGR2RGB)
    plt.subplot(6,5,c)
    plt.imshow(img)
    plt.axis('off')
    c+=1
